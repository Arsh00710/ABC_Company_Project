# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('ABC_data.csv')
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
#Display the first few rows of the dataset
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#Display the last few rows of the dataset
data.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
#Display concise summary of a DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
# Display statistical summary of the dataFram
data.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
#         Height      Weight   College        Salary
# count      458  458.000000       374  4.470000e+02
# unique      18         NaN       118           NaN
# top     06-Sep         NaN  Kentucky           NaN
# freq        59         NaN        22           NaN
# mean       NaN  221.543668       NaN  4.833970e+06
# std        NaN   26.343200       NaN  5.226620e+06
# min        NaN  161.000000       NaN  3.088800e+04
# 25%        NaN  200.000000       NaN  1.025210e+06
# 50%        NaN  220.000000       NaN  2.836186e+06
# 75%        NaN  240.000000       NaN  6.500000e+06
# max        NaN  307.000000       NaN  2.500000e+07

# %%
#To check if there are any missing values in dataset
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#To check if there are any missing values in dataset
data.notnull().sum()
# Out:
# Name        458
# Team        458
# Number      458
# Position    458
# Age         458
# Height      458
# Weight      458
# College     374
# Salary      447
# dtype: int64

# %%
#To check if there are any duplicates in dataset
data.duplicated().sum()
# Out:
# 0

# %%
#To view all column names of DataFrame
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
#Display unique values in the 'Team' column of DataFrame
data.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
#To view Count of Unique values in the 'Team' column of DataFrame
data.Team.nunique()
# Out:
# 30

# %%
#To view values_Count  in the 'Team' column of DataFrame
data['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#Display unique values in the 'Position' column of DataFrame
data.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
#To view Count of Unique values in the 'Position' column of DataFrame
data.Position.nunique()
# Out:
# 5

# %%
#To view values_Count  in the 'Position' column of DataFrame
data['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#Display unique values in the 'College' column of DataFrame
data.College.unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State', nan,
#        'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State', 'Ohio State',
#        'Washington', 'Kentucky', 'North Carolina', 'Arizona',
#        'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford', 'Syracuse',
#        'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M', 'UCLA', 'UNLV',
#        'Wichita State', "Saint Joseph's", 'Notre Dame', 'Norfolk State',
#        'Duke', 'Murray State', 'Tennessee State', 'Bowling Green',
#        'Purdue', 'Wake Forest', 'Michigan', 'Missouri', 'USC',
#        'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson', 'Vanderbilt',
#        'Michigan State', 'Florida', 'Washington State', 'Arizona State',
#        'Oklahoma', 'Wyoming', "St. John's", 'Maryland', 'Wisconsin',
#        'Utah Valley', 'North Carolina State', 'UC Santa Barbara',
#        'Baylor', 'Connecticut', 'Oregon State', 'New Mexico', 'Oregon',
#        'Creighton', 'Arkansas', 'Memphis', "Saint Mary's", 'Tennessee',
#        'Alabama', 'Georgia', 'Colorado', 'Boston College', 'Temple',
#        'Fresno State', 'IUPUI', 'Eastern Washington', 'Western Michigan',
#        'Virginia', 'Northeastern', 'Western Kentucky', 'Nevada',
#        'Illinois', 'Kansas State', 'Charleston', 'Clemson',
#        'Blinn College', 'Providence', 'Detroit', 'Rhode Island',
#        'California', 'Cleveland State', 'Iowa State', 'Florida State',
#        'Long Beach State', 'Penn State', 'Indiana', 'San Diego State',
#        'Western Carolina', 'Houston', 'Xavier', 'Old Dominion',
#        'Minnesota', 'Louisiana Tech', 'Bucknell', 'Pittsburgh',
#        'Virginia Commonwealth', 'Harvard', 'Marshall', 'Iowa',
#        'St. Bonaventure', 'Louisiana-Lafayette', 'Colorado State',
#        'Virginia Tech', 'DePaul', 'Morehead State', 'Central Michigan',
#        'Weber State', 'Lehigh', 'Westchester CC', 'Dayton', 'Butler'],
#       dtype=object)

# %%
#To view Count of Unique values in the 'College' column of DataFrame
data.College.nunique()
# Out:
# 118

# %%
#To view values_Count  in the 'College' column of DataFrame
data['College'].value_counts()
# Out:
# College
# Kentucky           22
# Duke               20
# Kansas             19
# North Carolina     16
# UCLA               15
#                    ..
# Utah Valley         1
# Cleveland State     1
# Iowa State          1
# Florida State       1
# Baylor              1
# Name: count, Length: 118, dtype: int64

# %%
#STEP 4 - Data preprocessing

# Replace incorrect data in the 'height' column with random values between 150 and 180
data['Height'] = np.random.randint(150, 180, size=len(data))
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     159     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     153     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
# Correcting the 'college' column
# Assuming 'college' column contains categorical data and replacing incorrect values with 'Unknown'
data['College'].fillna("Unknown",inplace=True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     159     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     153     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4              Unknown  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454            Unknown   900000.0
# 455            Unknown  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
# Correcting the 'Salary' column
# Calculate the mean of valid salary values
mean_salary = round(data['Salary'].mean())
mean_salary
# Out:
# 4833970

# %%
# Fill NaN values in 'Salary' column with the rounded mean salary
data['Salary'].fillna(mean_salary, inplace=True)
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     159     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     153     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  4833970.0
# 3        Georgia State  1148640.0
# 4              Unknown  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454            Unknown   900000.0
# 455            Unknown  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
# Display the modified dataset
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     170     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     159     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     153     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University  4833970.0
# 3        Georgia State  1148640.0
# 4              Unknown  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454            Unknown   900000.0
# 455            Unknown  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
#Display the first few rows of the  modified dataset
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2   John Holland  Boston Celtics      30       SG   27     170     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     167     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University  4833970.0
# 3      Georgia State  1148640.0
# 4            Unknown  5000000.0

# %%
#Display the last few rows of the modified dataset
data.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight  College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     159     203   Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     157     179  Unknown
# 455  Tibor Pleiss  Utah Jazz      21        C   26     168     256  Unknown
# 456   Jeff Withey  Utah Jazz      24        C   26     153     231   Kansas
# 457      Priyanka  Utah Jazz      34        C   25     163     231   Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
#Display concise summary of a modified DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %%
# Display statistical summary of the modified dataFram
data.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
#             Height      Weight  College        Salary
# count   458.000000  458.000000      458  4.580000e+02
# unique         NaN         NaN      119           NaN
# top            NaN         NaN  Unknown           NaN
# freq           NaN         NaN       84           NaN
# mean    164.519651  221.543668      NaN  4.833970e+06
# std       8.474227   26.343200      NaN  5.163335e+06
# min     150.000000  161.000000      NaN  3.088800e+04
# 25%     157.000000  200.000000      NaN  1.100150e+06
# 50%     164.000000  220.000000      NaN  2.862190e+06
# 75%     172.000000  240.000000      NaN  6.323553e+06
# max     179.000000  307.000000      NaN  2.500000e+07

# %%
#To check if there are any missing values in  modified dataset
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#To check if there are any not null values  in  modified dataset
data.notnull().sum()
# Out:
# Name        458
# Team        458
# Number      458
# Position    458
# Age         458
# Height      458
# Weight      458
# College     458
# Salary      458
# dtype: int64

# %%
#To check if there are any duplicates  in  modified dataset
data.duplicated().sum()
# Out:
# 0

# %%
#step5:Exploratory Data Analysis (EDA) and Visualization


# 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# Count the number of employees in each team

team_counts = data['Team'].value_counts()
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
# Calculate the percentage splitting with respect to the total employees
team_percentage = round((team_counts / len(data)) * 100,2)
team_percentage
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# Name: count, dtype: float64

# %%
# Create a new DataFrame with the results
team_table = pd.DataFrame({'Team': team_counts.index, 'Number of Employees': team_counts.values, 'Percentage': team_percentage.values})
team_table
# Out:
#                       Team  Number of Employees  Percentage
# 0     New Orleans Pelicans                   19        4.15
# 1        Memphis Grizzlies                   18        3.93
# 2                Utah Jazz                   16        3.49
# 3          New York Knicks                   16        3.49
# 4          Milwaukee Bucks                   16        3.49
# 5            Brooklyn Nets                   15        3.28
# 6   Portland Trail Blazers                   15        3.28
# 7    Oklahoma City Thunder                   15        3.28
# 8           Denver Nuggets                   15        3.28
# 9       Washington Wizards                   15        3.28
# 10              Miami Heat                   15        3.28
# 11       Charlotte Hornets                   15        3.28
# 12           Atlanta Hawks                   15        3.28
# 13       San Antonio Spurs                   15        3.28
# 14         Houston Rockets                   15        3.28
# 15          Boston Celtics                   15        3.28
# 16          Indiana Pacers                   15        3.28
# 17         Detroit Pistons                   15        3.28
# 18     Cleveland Cavaliers                   15        3.28
# 19           Chicago Bulls                   15        3.28
# 20        Sacramento Kings                   15        3.28
# 21            Phoenix Suns                   15        3.28
# 22      Los Angeles Lakers                   15        3.28
# 23    Los Angeles Clippers                   15        3.28
# 24   Golden State Warriors                   15        3.28
# 25         Toronto Raptors                   15        3.28
# 26      Philadelphia 76ers                   15        3.28
# 27        Dallas Mavericks                   15        3.28
# 28           Orlando Magic                   14        3.06
# 29  Minnesota Timberwolves                   14        3.06

# %%
# The table offers a comprehensive overview of employee distribution across various teams, detailing the employee count within each team and the corresponding percentage share relative to the total workforce. Notably, the "New Orleans Pelicans" boast the highest number of employees, accounting for approximately 4.15% of the total workforce. Conversely, teams such as the "Minnesota Timberwolves" and "Orlando Magic" exhibit lower percentages, each constituting around 3.06% of the total employee count. This data provides valuable insights for organizational planning and resource allocation, facilitating informed decision-making in managing human resources effectively.

# %%
# Plotting the bar chart with Seaborn

plt.figure(figsize=(12, 6))
sns.barplot(x='Team', y='Percentage', data=team_table, palette='viridis')
plt.title('Percentage of Employees in Each Team')
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\aarsh\AppData\Local\Temp\ipykernel_4900\894337933.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Team', y='Percentage', data=team_table, palette='viridis')

# %%
# Data Story:
#The visualization presents a breakdown of employee distribution across various teams within ABC Company, offering a snapshot of the workforce composition.

#Team Sizes:
#The data reveals that the New Orleans Pelicans boast the largest workforce with 19 employees, closely followed by the Memphis Grizzlies with 18 employees. This suggests a notable presence of personnel within these teams.

#Percentage Distribution:
#Each team's percentage representation denotes its contribution to the overall employee count. The New Orleans Pelicans stand out with the highest percentage at 4.15%, indicating a substantial share of the company's workforce.

#Consistency:
#Several teams maintain a consistent employee count, hovering around 15 individuals. Examples include the Brooklyn Nets, Portland Trail Blazers, and Oklahoma City Thunder, resulting in comparable percentage values.

#Variation:
#Conversely, certain teams such as the Orlando Magic and Minnesota Timberwolves exhibit a slightly lower percentage of 3.06%, indicating a smaller fraction of the total employee pool.

#Significance of New Orleans Pelicans:
#The New Orleans Pelicans emerge as a significant force within the organization, commanding the highest percentage share. Potential factors driving their sizable presence may include involvement in major projects, strategic initiatives, or serving as a pivotal department within the company.

#Comparison of Orlando Magic & Minnesota Timberwolves:
#Both the Orlando Magic and Minnesota Timberwolves demonstrate similar proportions, each representing 3.06% of the total workforce. This similarity in percentages suggests comparable contributions from these teams, albeit at a lower scale compared to others.

# %%
#2.Segregate the employees w.r.t different positions.

#Create a new DataFrame with 'Name' and 'Position' columns
name_position_table = data[['Name', 'Position']]
name_position_table
# Out:
#               Name Position
# 0    Avery Bradley       PG
# 1      Jae Crowder       SF
# 2     John Holland       SG
# 3      R.J. Hunter       SG
# 4    Jonas Jerebko       PF
# ..             ...      ...
# 453   Shelvin Mack       PG
# 454      Raul Neto       PG
# 455   Tibor Pleiss        C
# 456    Jeff Withey        C
# 457       Priyanka        C
#
# [458 rows x 2 columns]

# %%
#Segregate employees by positions
position_counts = data['Position'].value_counts().reset_index()
position_counts.columns = ['Position', 'Number of Employees ']
position_counts
# Out:
#   Position  Number of Employees
# 0       SG                   102
# 1       PF                   100
# 2       PG                    92
# 3       SF                    85
# 4        C                    79

# %%
#Plotting with Seaborn countplot

plt.figure(figsize=(12, 6))
sns.countplot(x='Position', data=name_position_table, palette='muted')
plt.title('Number of Employees in Each Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.show()
# Out:
# C:\Users\aarsh\AppData\Local\Temp\ipykernel_4900\3160893595.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Position', data=name_position_table, palette='muted')

# %%
#Data Story:
#The countplot visualizes the distribution of employees across different positions within the organization, providing insights into the workforce composition.

#Position Counts:

#Shooting Guard (SG): 102 employees
#Power Forward (PF): 100 employees
#Point Guard (PG): 92 employees
#Small Forward (SF): 85 employees
#Center (C): 79 employees
#Analysis:

#Shooting Guard (SG) stands out with the highest count among positions, indicating a substantial presence of employees in this role. This suggests a potential emphasis on skills associated with the Shooting Guard position, reflecting the company's strategic focus.
#Power Forward (PF) closely follows SG in count, signifying a significant representation of this position within the organization. The notable presence of Power Forwards may indicate their importance in the company's structure or project requirements.
#Point Guard (PG), while slightly lower in count compared to SG and PF, still demonstrates a considerable representation. PGs may play crucial roles in facilitating tasks or projects, contributing to the company's operational effectiveness.
#Small Forward (SF) shows a reasonable count, suggesting a notable presence within the organization. Employees in the Small Forward position often possess versatility, potentially contributing to diverse responsibilities within the company.
#Center (C) exhibits a slightly lower count compared to other positions. The specialized nature of the Center position may result in fewer individuals being required in this role, tailored to the company's specific needs and operational requirements.

# %%
# 3.Find from which age group most of the employees belong to.

#To view values_Count  in the 'Age' column of DataFrame for Find from which age group most of the employees belong to.
age_distribution = data['Age'].value_counts().reset_index()
age_distribution.columns = ['Age', 'No of Employees']
age_distribution
# Out:
#     Age  No of Employees
# 0    24               47
# 1    25               46
# 2    27               41
# 3    23               41
# 4    26               36
# 5    28               31
# 6    30               31
# 7    29               28
# 8    22               26
# 9    31               22
# 10   20               19
# 11   21               19
# 12   33               14
# 13   32               13
# 14   34               10
# 15   36               10
# 16   35                9
# 17   37                4
# 18   38                4
# 19   40                3
# 20   39                2
# 21   19                2

# %%
# Their are 47 employees aged 24, 46 employees aged 25.

# %%
#Plotting the age distribution using countplot

plt.figure(figsize=(12, 6))
sns.countplot(x='Age', data=data)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.show()

# %%
#Age group analysis
age_groups = pd.cut(data['Age'], bins=[15, 20, 25, 30,35, 40, 45], labels=['15-20', '20-25', '25-30', '30-35', '35-40','40-45'])
age_group_counts = age_groups.value_counts().reset_index()
age_group_counts.columns=['Age group','Number of Employees']
age_group_counts
# Out:
#   Age group  Number of Employees
# 0     20-25                  179
# 1     25-30                  167
# 2     30-35                   68
# 3     35-40                   23
# 4     15-20                   21
# 5     40-45                    0

# %%
# Plotting the age group distribution using barplot

plt.figure(figsize=(10, 6))
sns.barplot(x='Age group', y='Number of Employees', data=age_group_counts, palette='colorblind')
plt.title('Distribution of Employees Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()
# Out:
# C:\Users\aarsh\AppData\Local\Temp\ipykernel_4900\2598276402.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age group', y='Number of Employees', data=age_group_counts, palette='colorblind')

# %%
# 4.Find out under which team and position, spending in terms of salary is high.

# Group the salary by Team and Position, and calculate the sum of salaries for each group
team_position_salary = data.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
team_position_salary
# Out:
#                    Team Position      Salary
# 0         Atlanta Hawks        C  22756250.0
# 1         Atlanta Hawks       PF  23952268.0
# 2         Atlanta Hawks       PG   9763400.0
# 3         Atlanta Hawks       SF   6000000.0
# 4         Atlanta Hawks       SG  10431032.0
# ..                  ...      ...         ...
# 144  Washington Wizards        C  24490429.0
# 145  Washington Wizards       PF  11300000.0
# 146  Washington Wizards       PG  18022415.0
# 147  Washington Wizards       SF  11158800.0
# 148  Washington Wizards       SG  11356992.0
#
# [149 rows x 3 columns]

# %%
# Team and position, spending in terms of salary is high.
max_total_salary_index = team_position_salary['Salary'].idxmax()
max_total_salary_row = team_position_salary.loc[max_total_salary_index]
max_total_salary_row
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              31866445.0
# Name: 67, dtype: object

# %%
#Display in descending order of salary
team_position_total_desc = team_position_salary.sort_values(by='Salary', ascending=False)
team_position_total_desc.columns = ['Team', 'Position', 'Total Salary Spending']
team_position_total_desc.reset_index(drop=True, inplace=True)
team_position_total_desc
# Out:
#                    Team Position  Total Salary Spending
# 0    Los Angeles Lakers       SF             31866445.0
# 1            Miami Heat       PF             31538671.0
# 2       Houston Rockets       SG             28122883.0
# 3          Phoenix Suns       PG             28002998.0
# 4        Denver Nuggets       SF             27982771.0
# ..                  ...      ...                    ...
# 144     Milwaukee Bucks       SF              3104287.0
# 145  Philadelphia 76ers       SF              1845059.0
# 146    Sacramento Kings       PF              1370152.0
# 147          Miami Heat        C               981348.0
# 148       Orlando Magic       SF               845059.0
#
# [149 rows x 3 columns]

# %%
# Create scatterplot plot for total salary spending across different teams and positions

plt.figure(figsize=(14, 8))
sns.scatterplot(x='Team', y='Total Salary Spending', hue='Position',data=team_position_total_desc)
plt.title('Total Salary Spending Across Teams and Positions')
plt.xlabel('Team')
plt.ylabel('Total Salary Spending')
plt.xticks(rotation=90)
plt.show()

# %%
# Create bar plot for total salary spending across different teams and positions

plt.figure(figsize=(14, 8))
sns.barplot(x='Team', y='Total Salary Spending', hue='Position', data=team_position_total_desc)
plt.title('Total Salary Spending Across Teams and Positions')
plt.xlabel('Team')
plt.ylabel('Total Salary Spending')
plt.xticks(rotation=90)
plt.show()

# %%
     #Create a DataFrame with 'Age' and 'Salary' columns

age_salary_data = data[['Age', 'Salary']]
age_salary_data
# Out:
#      Age     Salary
# 0     25  7730337.0
# 1     25  6796117.0
# 2     27  4833970.0
# 3     22  1148640.0
# 4     29  5000000.0
# ..   ...        ...
# 453   26  2433333.0
# 454   24   900000.0
# 455   26  2900000.0
# 456   26   947276.0
# 457   25   947276.0
#
# [458 rows x 2 columns]

# %%
#Calculate the correlation matrix

correlation_matrix = age_salary_data.corr()
correlation_matrix
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %%
#Plotting the heatmap

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap: Age vs. Salary')
plt.show()

# %%
# The heatmap visually represents the correlation matrix.
